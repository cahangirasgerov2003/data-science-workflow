# %% [markdown]
# <img src="pandas-anatomy-of-a-dataframe.png" />

# %%
from matplotlib.image import imread

# %%
image_ndarray = imread("pandas-anatomy-of-a-dataframe.png")

# %%
image_ndarray.ndim
# Out:
# 3

# %%
image_ndarray.size
# Out:
# 8770176

# %%
image_ndarray.shape
# Out:
# (1104, 1986, 4)
