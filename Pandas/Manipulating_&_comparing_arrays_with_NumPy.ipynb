# %%
import numpy as np

# %%
# Arithmetic
a1 = np.array([1,2,4])
a1
# Out:
# array([1, 2, 4])

# %%
a1 + 2
# Out:
# array([3, 4, 6])

# %%
a2 = np.random.randint(1, 10, size = (2, 3))
a2
# Out:
# array([[6, 9, 6],
#        [7, 1, 8]], dtype=int32)

# %%
a2 * 10
# Out:
# array([[60, 90, 60],
#        [70, 10, 80]], dtype=int32)

# %%
a1
# Out:
# array([1, 2, 4])

# %%
a2
# Out:
# array([[6, 9, 6],
#        [7, 1, 8]], dtype=int32)

# %%
a2 * a1
# Out:
# array([[ 6, 18, 24],
#        [ 7,  2, 32]])

# %%
rng = np.random.default_rng(0)
a3 = rng.integers(1, 10, (2,3,3))
a3
# Out:
# array([[[8, 6, 5],
#         [3, 3, 1],
#         [1, 1, 2]],
#
#        [[8, 6, 9],
#         [5, 6, 9],
#         [7, 6, 5]]])

# %%
# Reshape
a2 = np.resize(a2, (3, 3))
a2
# Out:
# array([[6, 9, 6],
#        [7, 1, 8],
#        [6, 9, 6]], dtype=int32)

# %%
a2 * a3
# Out:
# array([[[48, 54, 30],
#         [21,  3,  8],
#         [ 6,  9, 12]],
#
#        [[48, 54, 54],
#         [35,  6, 72],
#         [42, 54, 30]]])

# %%
# Arithmetic
a1 / a2
# Out:
# array([[0.16666667, 0.22222222, 0.66666667],
#        [0.14285714, 2.        , 0.5       ],
#        [0.16666667, 0.22222222, 0.66666667]])

# %%
a1.dtype
# Out:
# dtype('int64')

# %%
a2.dtype
# Out:
# dtype('int32')

# %%
# Floor() or //
a1 // a2
# Out:
# array([[0, 0, 0],
#        [0, 2, 0],
#        [0, 0, 0]])

# %%
a1 ** a2
# Out:
# array([[    1,   512,  4096],
#        [    1,     2, 65536],
#        [    1,   512,  4096]])

# %%
a1 % a2
# Out:
# array([[1, 2, 4],
#        [1, 0, 4],
#        [1, 2, 4]])

# %%
np.mod(a1, a2)
# Out:
# array([[1, 2, 4],
#        [1, 0, 4],
#        [1, 2, 4]])

# %%
# e number ----- exponential
# e ^ 2
np.exp(2)
# Out:
# np.float64(7.38905609893065)

# %%
np.exp(a1)
# Out:
# array([ 2.71828183,  7.3890561 , 54.59815003])

# %%
# Log ----- ln
np.log(np.e)
# Out:
# np.float64(1.0)
