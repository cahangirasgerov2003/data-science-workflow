# %% [markdown]
# # NumPy sort arrays

# %%
import numpy as np
import pandas as pd

# %%
a1 = np.array([10, 55, 3, 100])
a1
# Out:
# array([ 10,  55,   3, 100])

# %%
rng = np.random.default_rng(100)
a2 = rng.integers(0, 10, (2, 3))
a2
# Out:
# array([[7, 8, 1],
#        [5, 0, 2]])

# %%
sorted_a1 = np.sort(a1)
sorted_a1
# Out:
# array([  3,  10,  55, 100])

# %%
np.sort(a2, axis = 0)
# Out:
# array([[5, 0, 1],
#        [7, 8, 2]])

# %%
np.sort(a2)
# Out:
# array([[1, 7, 8],
#        [0, 2, 5]])

# %%
np.argmax(a1)
# Out:
# np.int64(3)

# %%
np.argmin(a1)
# Out:
# np.int64(2)

# %%
a2
# Out:
# array([[7, 8, 1],
#        [5, 0, 2]])

# %%
np.argmax(a2, axis = 0)
# Out:
# array([0, 0, 1])

# %% [markdown]
# # NumPy sort array descending

# %%
a2_dataframe = pd.DataFrame(a2, index = ["Math", "English"], columns = ["1", "3", "5"])
a2_dataframe
# Out:
#          1  3  5
# Math     7  8  1
# English  5  0  2

# %%
a1, a1.shape
# Out:
# (array([ 10,  55,   3, 100]), (4,))

# %%
columns = np.array([1, 3, 5, 7])

# %%
a1_dataframe = pd.DataFrame(a1.reshape(1, 4), index = ["Student"], columns = columns)
a1_dataframe
# Out:
#           1   3  5    7
# Student  10  55  3  100

# %%
indexes = np.argsort(a1)[::-1]
indexes
# Out:
# array([3, 2, 1, 0])

# %%
a1 = a1[indexes]
a1
# Out:
# array([100,  55,  10,   3])

# %%
columns = columns[indexes]
columns
# Out:
# array([7, 3, 1, 5])

# %%
a1_dataframe
# Out:
#          5   1   3    7
# Student  3  10  55  100

# %%
a1_dataframe =  pd.DataFrame(a1.reshape(1, 4), index = ["Student"], columns = columns)
a1_dataframe
# Out:
#            7   3   1  5
# Student  100  55  10  3

# %%
a1_than_20 = a1_dataframe[a1_dataframe[7] > 20]
a1_than_20
# Out:
#            7   3   1  5
# Student  100  55  10  3

# %%
a1_than_20[5]
# Out:
# Student    3
# Name: 5, dtype: int64

# %%
a2_dataframe
# Out:
#          1  3  5
# Math     7  8  1
# English  5  0  2

# %%
cols = a2_dataframe.loc["Math"] > 5
a2_dataframe.loc[["Math", "English"], result]
# Out:
#          1  3
# Math     7  8
# English  5  0
