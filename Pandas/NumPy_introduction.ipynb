# %% [markdown]
# # NumPy DataTypes & Attributes

# %%
import numpy as np

# %%
# NumPy's main dataype is ndarray

# %%
a1 = np.array([1, 2, 3])
a1
# Out:
# array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %%
a2 = np.array([[1,2,3], [4,5,6]])
a2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a3 = np.array([
               [[1,2,3], [3,4,5]], 
               [[5,6,7], [7,8,9]],
               [[9,10,11],[11,12,13]]
              ])
a3
# Out:
# array([[[ 1,  2,  3],
#         [ 3,  4,  5]],
#
#        [[ 5,  6,  7],
#         [ 7,  8,  9]],
#
#        [[ 9, 10, 11],
#         [11, 12, 13]]])

# %%
a1.dtype, a2.dtype, a3.dtype
# Out:
# (dtype('int64'), dtype('int64'), dtype('int64'))

# %%
type(a3)
# Out:
# numpy.ndarray

# %%
a1.size, a2.size, a3.size
# Out:
# (3, 6, 18)

# %%
a1.shape, a2.shape, a3.shape
# Out:
# ((3,), (2, 3), (3, 2, 3))

# %%
import pandas as pd

# %%
a1.ndim, a2.ndim, a3.ndim
# Out:
# (1, 2, 3)

# %%
pd.DataFrame({"Make":["BMW", "Audi", "Opel"], "Colour":["Red", "Blue", "Black"]})
# Out:
#    Make Colour
# 0   BMW    Red
# 1  Audi   Blue
# 2  Opel  Black

# %%
df = pd.DataFrame(columns=["A", "B"], data=[[1,2]])
df
# Out:
#    A  B
# 0  1  2

# %%
dataframe = pd.DataFrame(a2)
dataframe
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df2 = pd.DataFrame(a3)
df2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df2 = pd.DataFrame(a3)
#       2 df2
#
# File ~\Desktop\Data_Science_Course\Pandas_exercise_1\env\lib\site-packages\pandas\core\frame.py:831, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     820         mgr = dict_to_mgr(
#     821             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     822             # attribute "name"
#    (...)
#     828             copy=_copy,
#     829         )
#     830     else:
# --> 831         mgr = ndarray_to_mgr(
#     832             data,
#     833             index,
#     834             columns,
#     835             dtype=dtype,
#     836             copy=copy,
#     837             typ=manager,
#     838         )
#     840 # For data is list-like, or Iterable (will consume into list)
#     841 elif is_list_like(data):
#
# File ~\Desktop\Data_Science_Course\Pandas_exercise_1\env\lib\site-packages\pandas\core\internals\construction.py:314, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     312     else:
#     313         values = np.asarray(values)
# --> 314     values = _ensure_2d(values)
#     316 else:
#     317     # by definition an array here
#     318     # the dtypes will be coerced to a single dtype
#     319     values = _prep_ndarraylike(values, copy=copy_on_sanitize)
#
# File ~\Desktop\Data_Science_Course\Pandas_exercise_1\env\lib\site-packages\pandas\core\internals\construction.py:592, in _ensure_2d(values)
#     590     values = values.reshape((values.shape[0], 1))
#     591 elif values.ndim != 2:
# --> 592     raise ValueError(f"Must pass 2-d input. shape={values.shape}")
#     593 return values
#
# ValueError: Must pass 2-d input. shape=(3, 2, 3)
