# %%
import numpy as np

# %%
a1 = np.array([1, 6, 4])

# %%
a1.ndim, a1.shape, a1.size
# Out:
# (1, (3,), 3)

# %%
rng = np.random.default_rng(0)
a2 = rng.integers(0, 10, size = (2, 3))
a2
# Out:
# array([[8, 6, 5],
#        [2, 3, 0]])

# %%
a1 > a2
# Out:
# array([[False, False, False],
#        [False,  True,  True]])

# %%
a1 >= a2
# Out:
# array([[False,  True, False],
#        [False,  True,  True]])

# %%
a1 > 1
# Out:
# array([False,  True,  True])

# %%
a1 == a2
# Out:
# array([[False,  True, False],
#        [False, False, False]])
